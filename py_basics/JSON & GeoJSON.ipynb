# %%
geojson_string = '''
{
  "type": "FeatureCollection",
  "features": [
    {"type": "Feature",
      "properties": {"name": "San Francisco"},
      "geometry": {"type": "Point", "coordinates": [-121.5687, 37.7739]}
    }
  ]
}
'''
print(geojson_string)

import json

data = json.loads(geojson_string)
print(type(data))
print(data)
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {"type": "Feature",
#       "properties": {"name": "San Francisco"},
#       "geometry": {"type": "Point", "coordinates": [-121.5687, 37.7739]}
#     }
#   ]
# }
#
# <class 'dict'>
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'San Francisco'}, 'geometry': {'type': 'Point', 'coordinates': [-121.5687, 37.7739]}}]}

# %%
print(data["type"])
print(data["features"])
print(data["features"][0])
features_dict = data["features"][0]

print(features_dict)









# data_features = data["features"]
# print(data_features)
# dict_1 = data_features[0]


# # print(data_features[])
# property_name = dict_1["properties"]
# geometry_type = dict_1["geometry"]["type"]
# geometry_coordinates = dict_1["geometry"]["coordinates"]
# Out:
# FeatureCollection
# [{'type': 'Feature', 'properties': {'name': 'San Francisco'}, 'geometry': {'type': 'Point', 'coordinates': [-121.5687, 37.7739]}}]
# {'type': 'Feature', 'properties': {'name': 'San Francisco'}, 'geometry': {'type': 'Point', 'coordinates': [-121.5687, 37.7739]}}
